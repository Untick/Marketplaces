# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/Marketplaces/blob/Prusov-Maxim-branch/Prusov%20Maxim/%D0%A1%D1%82%D0%B0%D0%B6%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B0_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Заметки для последующей работы:
#
# - график по ключевым параметрам удобно вывести в виде столбчатой диаграммы по месяцам

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Описание вводных данных

# %% [markdown]
# Файлы "Аналитика Акции" и "Аналитика графики" содержат данные по уникальным посетителям, заказам товаров, сумм заказов и некоторые другие.
#
# По сути файлы отличаются несколькими графами, и данные графиков есть в полном объёме в акциях, что делает его бессмысленным.
#
# Странности в данных:
#
# - заказ товара не всегда учитывается, как заказ товара по акции, хотя активная акция в этот период стоит.
# - количество заказанных товаров и количество доставленных товаров может отличаться.
#
# В папке "Товары по категориям" содержится описание товаров по структуре Озона
#
# Файл "База" содержит артикулы и озон-ид всех товаров компании, плюс некоторые данные состояния товаров.
#
# !можно отсюда брать соответствие озон-ид и артикула в базе клиента и внутри остальных данных клиента привязываться по артикулу, потому как озон-ид указан только в аналитике.
#
# !через озон-ид можно связывать данные от разных килентов.
#
#
# Вопросы:
#
# 1. озон-ид одинаковый у всех продавцов, если товар один?
# 2. Внутри товарной категории у разных продавцов один и тот же товар называется одинаково?

# %% [markdown]
# # Выводы по данным

# %% [markdown]
# ![Модель покупки товара.png](data:image/png;base64,...)

# %% [markdown]
# Если обобщить, то представленные данные являются описанием воздействия продавца на некоторые факторы, которые, по его мнению, влияют на продажи, и обратная связь от площадки и посетителей площадки.
#
# С точки зрения запроса заказчика
#
# - Прогнозирование продаж для любого клиента в категории на основе общих продаж всех продавцов в этой категории.
# - Прогнозирование продаж товара в нескольких вариантах с учетом данных общих продаж, статистики товара и аудита карточки товара.
#
# данные не имеют практического смысла, поскольку все они описывают деятельность конкретного продавца и могут быть использованы в качестве оценки эффективности тех или иных действий данного продавца.
#
# Прогноз продаж для любого клиента означает, что я, как клиент, могу получить прогноз по продаже моего товара на основании данных от других продавцов, что бессмысленно, поскольку результативность других продавцов зависит от их действий, а моя от моих. Если я не сделаю ряд действий, оказывающих влияние на вероятность покупки товара, вероятность покупки моего товара не изменится, какой бы ни была вероятность продажи этого товара у других продавцов.
#
# На основании имеющихся данных можно попытаться выделить пул доступных действий на площадке для влияния на покупателя, и определить наиболее удачное содержание каждого конкретного действия.
#
# Например, в пуле могут быть следующие возможные действия для продаца:
# - поднять свой товар в поиске
# - заполнить карточку товара
# - сформировать ряд отзывов на товар
# - провести рекламную компанию
# - и т.д.
#
# И далее в каждом действии наиболее удачное содержание
# - нахождение в поиске на позиции с 1 по 5 даёт наибольший прирост к продажам
# - нилучшая структура заполнения карточки такая (описание)
# - и т.д.
