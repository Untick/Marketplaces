# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/Marketplaces/blob/Romanov-Sergey-branch/Romanov%20Sergey/%E2%96%B2_%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B0%D1%8F_%D1%82%D0%B5%D1%82%D1%80%D0%B0%D0%B4%D1%8C_%D0%9C%D0%90%D0%A0%D0%9A%D0%95%D0%A2%D0%9F%D0%9B%D0%AD%D0%99%D0%A1%D0%AB_%D0%A1%D0%B5%D1%80%D0%B3%D0%B5%D0%B9_%D0%A0%D0%BE%D0%BC%D0%B0%D0%BD%D0%BE%D0%B2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Загрузка модуля pandas
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_base = pd.read_excel('/content/drive/MyDrive/Marketplaces/Аналитика Графики 01.06.2022-31.05.2023.xlsx')
data_promo = pd.read_excel('/content/drive/MyDrive/Marketplaces/Аналитика Акции 01.06.2022-31.05.2023.xlsx')

# %%
data_base.head()
# Out:
#        Категория 3-го уровня                         Товары  \
# 0  Разное автопринадлежности  Светодиодная подсветка салона
# 1  Разное автопринадлежности  Светодиодная подсветка салона
# 2  Разное автопринадлежности  Светодиодная подсветка салона
# 3  Разное автопринадлежности  Светодиодная подсветка салона
# 4  Разное автопринадлежности  Светодиодная подсветка салона
#
#                           Модель    Ozon ID Артикул        День  \
# 0  Светодиодная подсветка салона  882353426   34414  2023-03-03
# 1  Светодиодная подсветка салона  882353426   34414  2023-03-05
# 2  Светодиодная подсветка салона  882353427   34414  2023-03-05
# 3  Светодиодная подсветка салона  882353427   34414  2023-03-06
# 4  Светодиодная подсветка салона  882353427   34414  2023-03-07
#
#    Уникальные посетители, всего  \
# 0                             1
# 1                             1
# 2                            65
# 3                            85
# 4                            44
#
# ...

# %%
data_promo.head()
# Out:
#        Категория 3-го уровня                         Товары  \
# 0  Разное автопринадлежности  Светодиодная подсветка салона
# 1  Разное автопринадлежности  Светодиодная подсветка салона
# 2  Разное автопринадлежности  Светодиодная подсветка салона
# 3  Разное автопринадлежности  Светодиодная подсветка салона
# 4  Разное автопринадлежности  Светодиодная подсветка салона
#
#                           Модель    Ozon ID  Артикул Акции        День  \
# 0  Светодиодная подсветка салона  882353427    34414   NaN  2023-03-05
# 1  Светодиодная подсветка салона  882353427    34414   NaN  2023-03-06
# 2  Светодиодная подсветка салона  882353427    34414   NaN  2023-03-07
# 3  Светодиодная подсветка салона  882353427    34414   NaN  2023-03-08
# 4  Светодиодная подсветка салона  882353427    34414   NaN  2023-03-09
#
#    Уникальные посетители, всего  \
# 0                            65
# 1                            85
# 2                            44
# 3                            47
# ...

# %%
# Смотрим размерность фрэймов
print(data_base.shape)
print(data_promo.shape)
# Out:
# (254748, 19)
# (239957, 20)

# %%
# Смотрим названия столбцов в основном фрэйме
for i in data_base.columns:
  print(i)
# Out:
# Категория 3-го уровня
# Товары
# Модель
# Ozon ID
# Артикул
# День
# Уникальные посетители, всего
# Уникальные посетители с просмотром карточки товара
# Показы, всего
# Показы на карточке товара
# Показы в поиске и каталоге
# Позиция в поиске и каталоге
# В корзину, всего
# Заказано товаров
# Отменено товаров
# Доставлено (за выбранный период)
# Возвращено товаров
# Заказано на сумму
# Отправления с премиум-подпиской, принятые в обработку

# %%
# Смотрим названия столбцов в акционном фрэйме
for i in data_promo.columns:
  print(i)
# Out:
# Категория 3-го уровня
# Товары
# Модель
# Ozon ID
# Артикул
# Акции
# День
# Уникальные посетители, всего
# Уникальные посетители с просмотром карточки товара
# Показы, всего
# Показы на карточке товара
# Показы в поиске и каталоге
# Позиция в поиске и каталоге
# В корзину, всего
# Заказано товаров
# Доставлено (за выбранный период)
# Заказано на сумму
# Заказано товаров по акции
# Заказано на сумму по акции
# Отправления с премиум-подпиской, принятые в обработку

# %% [markdown]
# # Преобразование столбцов День в DateTime-формат

# %%
# Смотрим тип данных и формат отображения в столбце День до преобразования
print(type(data_promo.loc[0,'День']))
print(data_promo.loc[0,'День'])
# Out:
# <class 'str'>
# 2023-03-05

# %%
# Функция принимает вектор и преобразует каждый его элемент в формат DateTime
def vector_to_time (vector):
  for i in range(vector.shape[0]):
    vector.iloc[i] = np.datetime64(vector.iloc[i])

# %%
# Преобразуем столбец День в DateTime
vector_to_time(data_promo.loc[:,'День'])
# Out:
# <ipython-input-10-8409ee1c5583>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vector.iloc[i] = np.datetime64(vector.iloc[i])

# %%
# Проверим тип и содержимое после преобразования в DateTime
print(type(data_promo.loc[0,'День']))
print(data_promo.loc[0,'День'])
# Out:
# <class 'numpy.datetime64'>
# 2023-03-05

# %%
# Преобразуем столбец День в DateTime
vector_to_time(data_base.loc[:,'День'])
# Out:
# <ipython-input-10-8409ee1c5583>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vector.iloc[i] = np.datetime64(vector.iloc[i])

# %%
# Проверим тип и содержимое после преобразования в DateTime
print(type(data_base.loc[0,'День']))
print(data_base.loc[0,'День'])
# Out:
# <class 'numpy.datetime64'>
# 2023-03-03

# %%
name_prod = data_base[(data_base['Ozon ID'] == 511574205)].iloc[0]
print(name_prod[1])

# %%
data_base = data_base.sort_values(by=['День'])
data_promo = data_promo.sort_values(by=['День'])

# %% [markdown]
# # Ищем количество позиций товара по Ozon ID

# %% [markdown]
# Нашел уникальные Ozon ID.

# %%
prod = []
id = []
for i in data_base['Ozon ID'].unique():
  id.append(i)
  prod.append(data_base[(data_base['Ozon ID'] == i)].iloc[0][1])

# %% [markdown]
# Видно, что у каждого наименования бывает несколько ID

# %%
df_prod_id = pd.DataFrame({'Ozon ID':id, 'Наименование товара': prod })
df_prod_id.head(50)
# Out:
#       Ozon ID                                Наименование товара
# 0   882353426                      Светодиодная подсветка салона
# 1   882353427                      Светодиодная подсветка салона
# 2   275493671        Светодиодные линзы Aozoom A3+ RU (комплект)
# 3   275493676        Светодиодные линзы Aozoom A3+ RU (комплект)
# 4   275500050            Светодиодные линзы Aozoom A7 (комплект)
# 5   275500058            Светодиодные линзы Aozoom A7 (комплект)
# 6   276736878  Фары противотуманные светодиодные MTF Light Ni...
# 7   276736881  Фары противотуманные светодиодные автомобильны...
# 8   276736896  Фары противотуманные светодиодные MTF Light Ni...
# 9   276736902  Фары противотуманные светодиодные автомобильны...
# 10  276738990  Фары противотуманные светодиодные автомобильны...
# 11  278434864  Стекло фары, GNX, левое, поликарбонат, для авт...
# 12  278437421  Стекло фары Volkswagen Touareg 2010-2014, лево...
# ...

# %%
print(df_prod_id.shape[0], '- уникальных значений по OZON ID')
print(len(prod1), '- уникальных значений по Товары (наименованию товара)')
# Out:
# 1233 - уникальных значений по OZON ID
# 998 - уникальных значений по Товары (наименованию товара)

# %% [markdown]
# # Подсчёт количества записей по каждому товару

# %%
prod1 = []
for i in data_base['Товары'].unique():
  prod1.append(i)

# %%
print(len(prod1))
for i in prod1:
  print(i)
# Out:
# 998
# Светодиодная подсветка салона
# Светодиодные линзы Aozoom A3+ RU (комплект)
# Светодиодные линзы Aozoom A7 (комплект)
# Фары противотуманные светодиодные MTF Light Nissan/INFINITI, 2 шт.
# Фары противотуманные светодиодные автомобильные MTF Light VW / SEAT, линза, 12В, 5000К, 10Вт, ЕСЕ R19, E4 комплект.
# Фары противотуманные светодиодные автомобильные MTF Light 12В, 22Вт, ЕСЕ R19, универсальные, комплект. Арт.: FL25W Citroen, Ford, Peugeot, Renault, Subaru, Mitsubishi, Nissan
# Стекло фары, GNX, левое, поликарбонат, для автомобилей Mercedes W218 CLS 2010-2014
# Стекло фары Volkswagen Touareg 2010-2014, левое, GNX, поликарбонат, для авто, автомобилей Фольксваген
# Переходная рамка Subaru Outback 4 2009-2014 для линз Hella 3R (ближний), GNX, для автомобилей Субару Аутбек
# Светодиодные линзы GNX Effective 3.0 (комплект)
# Биксеноновая линза GNX Hella 3R Crystal Vision, газоразрядная, ксенон (HID), D1S, D2S, D3S, D4S
# Светодиодные линзы Bi-Led AOZOOM A3 Max 5500K 3.0" (2 шт.)
# ...

# %%
prod_for_count = []
count_prod = []
for i in prod1:
  count_prod.append(data_base[(data_base['Товары'] == i)].shape[0])
  prod_for_count.append(i)

# %%
promo_for_count = []
count_promo = []
for i in prod1:
  count_promo.append(data_promo[(data_promo['Товары'] == i)].shape[0])
  promo_for_count.append(i)

# %%
df_promo_count = pd.DataFrame({'Наименование товара': promo_for_count, 'Количество записей(Акции)': count_promo})
df_promo_count.head(10)
# Out:
#                                  Наименование товара  \
# 0                      Светодиодная подсветка салона
# 1        Светодиодные линзы Aozoom A3+ RU (комплект)
# 2            Светодиодные линзы Aozoom A7 (комплект)
# 3  Фары противотуманные светодиодные MTF Light Ni...
# 4  Фары противотуманные светодиодные автомобильны...
# 5  Фары противотуманные светодиодные автомобильны...
# 6  Стекло фары, GNX, левое, поликарбонат, для авт...
# 7  Стекло фары Volkswagen Touareg 2010-2014, лево...
# 8  Переходная рамка Subaru Outback 4 2009-2014 дл...
# 9    Светодиодные линзы GNX Effective 3.0 (комплект)
#
#    Количество записей(Акции)
# 0                         88
# 1                        474
# 2                        352
# 3                          0
# 4                          0
# 5                          0
# 6                        291
# 7                        301
# 8                        367
# 9                          0

# %%
df_prod_count = pd.DataFrame({'Наименование товара': prod_for_count, 'Количество записей(Графики)': count_prod, })
df_prod_count.head(10)
# Out:
#                                  Наименование товара  \
# 0                      Светодиодная подсветка салона
# 1        Светодиодные линзы Aozoom A3+ RU (комплект)
# 2            Светодиодные линзы Aozoom A7 (комплект)
# 3  Фары противотуманные светодиодные MTF Light Ni...
# 4  Фары противотуманные светодиодные автомобильны...
# 5  Фары противотуманные светодиодные автомобильны...
# 6  Стекло фары, GNX, левое, поликарбонат, для авт...
# 7  Стекло фары Volkswagen Touareg 2010-2014, лево...
# 8  Переходная рамка Subaru Outback 4 2009-2014 дл...
# 9    Светодиодные линзы GNX Effective 3.0 (комплект)
#
#    Количество записей(Графики)
# 0                           90
# 1                          481
# 2                          353
# 3                           25
# 4                            2
# 5                            4
# 6                          291
# 7                          301
# 8                          368
# 9                          295

# %%
prod_promo_count = pd.merge(df_prod_count, df_promo_count, on ='Наименование товара')

# %%
prod_promo_count.head(10)
# Out:
#                                  Наименование товара  \
# 0                      Светодиодная подсветка салона
# 1        Светодиодные линзы Aozoom A3+ RU (комплект)
# 2            Светодиодные линзы Aozoom A7 (комплект)
# 3  Фары противотуманные светодиодные MTF Light Ni...
# 4  Фары противотуманные светодиодные автомобильны...
# 5  Фары противотуманные светодиодные автомобильны...
# 6  Стекло фары, GNX, левое, поликарбонат, для авт...
# 7  Стекло фары Volkswagen Touareg 2010-2014, лево...
# 8  Переходная рамка Subaru Outback 4 2009-2014 дл...
# 9    Светодиодные линзы GNX Effective 3.0 (комплект)
#
#    Количество записей(Графики)  Количество записей(Акции)
# 0                           90                         88
# 1                          481                        474
# 2                          353                        352
# 3                           25                          0
# 4                            2                          0
# ...

# %%
prod_promo_count = prod_promo_count.sort_values(by=['Количество записей(Графики)'], ascending=False)

# %%
prod_promo_count.head(10)
# Out:
#                                    Наименование товара  \
# 10   Биксеноновая линза GNX Hella 3R Crystal Vision...
# 326  Стекла фар Mazda 3 BK седан 2003-2009, комплек...
# 18                  Линзы для фар GNX Hella 3R H7, D2S
# 141  Стекло фары Toyota Camry V40 2006-2009, правое...
# 1          Светодиодные линзы Aozoom A3+ RU (комплект)
# 242  Стекло фары Ford Focus 2 2008-2010, левое, GNX...
# 210  Стекло фары Honda Civic 4D 8 седан 2006-2009, ...
# 103  Стекло фары Ford Focus 2 2005-2008, левое, GNX...
# 234  Стекло фары Ford Focus 3 2010-2015, правое, GN...
# 253  Стекло фары Mazda 3 BK седан (2003 - 2009 г.в....
#
#      Количество записей(Графики)  Количество записей(Акции)
# 10                           616                        616
# 326                          545                        545
# 18                           543                        543
# 141                          485                        485
# ...

# %% [markdown]
# #Строим графики

# %%
prod_promo_count.iloc[0, 0]
# Out:
# 'Биксеноновая линза GNX Hella 3R Crystal Vision, газоразрядная, ксенон (HID), D1S, D2S, D3S, D4S'

# %%
toto = prod_promo_count.iloc[2, 0]

# %%
x = data_base[(data_base['Товары'] == toto)].loc[:, 'День']
y1 = data_base[(data_base['Товары'] == toto)].loc[:, 'Заказано товаров']
y2 = data_promo[(data_promo['Товары'] == toto)].loc[:, 'Акции'].isna()


plt.figure(figsize=(10,3))
plt.plot(x, y1)
plt.plot(x, -y2)
plt.grid()
plt.xlabel('Время')
plt.ylabel('Заказано товаров')
plt.title(toto)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = data_base[(data_base['Товары'] == toto)].loc[:, 'День']
y1 = data_base[(data_base['Товары'] == toto)].loc[:, 'Заказано товаров']
y2 = data_promo[(data_promo['Товары'] == toto)].loc[:, 'Акции'].isna()


plt.figure(figsize=(10,3))
plt.plot(x, y1)
plt.plot(x, -y2)
plt.grid()
plt.xlabel('Время')
plt.ylabel('Заказано товаров')
plt.title(toto)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = data_base[(data_base['Товары'] == toto)].loc[:, 'День']
y1 = data_base[(data_base['Товары'] == toto)].loc[:, 'Заказано товаров']
y2 = data_promo[(data_promo['Товары'] == toto)].loc[:, 'Акции'].isna()


plt.figure(figsize=(10,3))
plt.plot(x, y1)
plt.plot(x, -y2)
plt.grid()
plt.xlabel('Время')
plt.ylabel('Заказано товаров')
plt.title(toto)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Корреляция по товарам

# %%
data_base.columns[6:]
# Out:
# Index(['Уникальные посетители, всего',
#        'Уникальные посетители с просмотром карточки товара', 'Показы, всего',
#        'Показы на карточке товара', 'Показы в поиске и каталоге',
#        'Позиция в поиске и каталоге', 'В корзину, всего', 'Заказано товаров',
#        'Отменено товаров', 'Доставлено (за выбранный период)',
#        'Возвращено товаров', 'Заказано на сумму',
#        'Отправления с премиум-подпиской, принятые в обработку'],
#       dtype='object')

# %%
parameter = list(data_base.columns[6:])
n_parameter = np.arange(13)

# %%
for i in range(len(parameter)):
  parameter[i] = f'{i+1} {parameter[i]}'
  print (parameter[i])
# Out:
# 1 Уникальные посетители, всего
# 2 Уникальные посетители с просмотром карточки товара
# 3 Показы, всего
# 4 Показы на карточке товара
# 5 Показы в поиске и каталоге
# 6 Позиция в поиске и каталоге
# 7 В корзину, всего
# 8 Заказано товаров
# 9 Отменено товаров
# 10 Доставлено (за выбранный период)
# 11 Возвращено товаров
# 12 Заказано на сумму
# 13 Отправления с премиум-подпиской, принятые в обработку

# %%
plt.figure(figsize=(10,10))        # создана зона для графика определённых пропорций
plt.imshow(data_base[(data_base['Товары'] == toto)].iloc[6:].corr(),cmap="gnuplot")
plt.colorbar() # цветовая полоса colorbar
plt.title(toto)
plt.yticks(n_parameter, parameter)
plt.xticks(n_parameter, n_parameter+1)
plt.show()
# Out:
# <ipython-input-39-e220faf8d48d>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.imshow(data_base[(data_base['Товары'] == toto)].iloc[6:].corr(),cmap="gnuplot")

# %%
plt.figure(figsize=(10,10))        # создана зона для графика определённых пропорций
plt.imshow(data_base[(data_base['Товары'] == toto)].iloc[6:].corr(),cmap="gnuplot")
plt.colorbar() # цветовая полоса colorbar
plt.title(toto)
plt.yticks(n_parameter, parameter)
plt.xticks(n_parameter, n_parameter+1)
plt.show()
# Out:
# <ipython-input-41-e220faf8d48d>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.imshow(data_base[(data_base['Товары'] == toto)].iloc[6:].corr(),cmap="gnuplot")

# %%
plt.figure(figsize=(10,10))        # создана зона для графика определённых пропорций
plt.imshow(data_base[(data_base['Товары'] == toto)].iloc[6:].corr(),cmap="gnuplot")
plt.colorbar() # цветовая полоса colorbar
plt.title(toto)
plt.yticks(n_parameter, parameter)
plt.xticks(n_parameter, n_parameter+1)
plt.show()
# Out:
# <ipython-input-43-e220faf8d48d>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.imshow(data_base[(data_base['Товары'] == toto)].iloc[6:].corr(),cmap="gnuplot")
