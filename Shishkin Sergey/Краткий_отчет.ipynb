# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/Marketplaces/blob/main/Shishkin%20Sergey/%D0%9A%D1%80%D0%B0%D1%82%D0%BA%D0%B8%D0%B9_%D0%BE%D1%82%D1%87%D0%B5%D1%82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Задание: Собираем таблицу данных по файлу метрики Заказчика.**

# %% [markdown]
# Изучил инструкцию по сбору данных Заказчика. Не увидел ничего нового, те же данные расписаны где находятся. Для предсказания продаж мною выборка была сделана ранее из ключевых показателей Клиента, общие данные категории в целом на продажи не влияют, а лиш ограничивают и в предсказании не участвуют.

# %% [markdown]
# **2. Задание: Завершение экспериментов с временными рядами.**

# %% [markdown]
# Провел ряд экспериментов и выбрал для наглядности строить график предсказания с реальными данными и для оценки вычислять метрику RMSE. На первом этапе решил максимально повысить точность и занялся тюнингом моделей на AutoKeras.
#
# 1 Этап. Модель ARIMA (гибридная) показала RSME 9.977
#
# 2 Этап. Модель регрессии на AutoKeras показала RSME 6.472
#
# 3 Этап. Модель регрессии на эволюционных алгоритмах показала RSME 0.9
#
# 4 Этап. Осваиваю временную модель на эволюционных алгоритмах использующую для предсказания целевого значения дополнительные данные в таблице (экзогенные переменные). Данный подход похож на регрессию но с учетом временного ряда, что должно повысить точность за счет того что модель будет видеть не только значения в один момент, но и предыдущие, т.е. "динамику" процесса. И возможно более точное предсказание на более дальний срок чем у классических моделей предсказания временного ряда.

# %% [markdown]
# 1. ARIMA
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. AutoKeras
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Регрессия (Эволюционная)
# ![image.png](data:image/png;base64,...)
